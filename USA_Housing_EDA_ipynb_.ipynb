# %% [markdown]
# ## NAME: ZAIN ATTIQ

# %% [markdown]
# # 1. Perform EDA on the Dataset Which should include

# %%
import pandas as pd
import numpy as np
import sklearn
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('/content/housing.csv')

# %%
df
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                  41          880           129.0
# 1        -122.22     37.86                  21         7099          1106.0
# 2        -122.24     37.85                  52         1467           190.0
# 3        -122.25     37.85                  52         1274           235.0
# 4        -122.25     37.85                  52         1627           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                  25         1665           374.0
# 20636    -121.21     39.49                  18          697           150.0
# 20637    -121.22     39.43                  17         2254           485.0
# 20638    -121.32     39.43                  18         1860           409.0
# 20639    -121.24     39.37                  16         2785           616.0
#
# ...

# %%
df.shape
# Out:
# (20640, 10)

# %% [markdown]
# it shows the no of rows and columns in the data

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20640 non-null  float64
#  1   latitude            20640 non-null  float64
#  2   housing_median_age  20640 non-null  int64
#  3   total_rooms         20640 non-null  int64
#  4   total_bedrooms      20433 non-null  float64
#  5   population          20640 non-null  int64
#  6   households          20640 non-null  int64
#  7   median_income       20640 non-null  float64
#  8   median_house_value  20640 non-null  int64
#  9   ocean_proximity     20640 non-null  object
# dtypes: float64(4), int64(5), object(1)
# memory usage: 1.6+ MB

# %% [markdown]
# it shows that the data is almost complete and the values are missing only in the total_bedrooms column

# %%
df.describe()
# Out:
#           longitude      latitude  housing_median_age   total_rooms  \
# count  20640.000000  20640.000000        20640.000000  20640.000000
# mean    -119.569704     35.631861           28.639486   2635.763081
# std        2.003532      2.135952           12.585558   2181.615252
# min     -124.350000     32.540000            1.000000      2.000000
# 25%     -121.800000     33.930000           18.000000   1447.750000
# 50%     -118.490000     34.260000           29.000000   2127.000000
# 75%     -118.010000     37.710000           37.000000   3148.000000
# max     -114.310000     41.950000           52.000000  39320.000000
#
#        total_bedrooms    population    households  median_income  \
# count    20433.000000  20640.000000  20640.000000   20640.000000
# mean       537.870553   1425.476744    499.539680       3.870671
# std        421.385070   1132.462122    382.329753       1.899822
# min          1.000000      3.000000      1.000000       0.499900
# ...

# %%
df.dtypes
# Out:
# longitude             float64
# latitude              float64
# housing_median_age      int64
# total_rooms             int64
# total_bedrooms        float64
# population              int64
# households              int64
# median_income         float64
# median_house_value      int64
# ocean_proximity        object
# dtype: object

# %% [markdown]
# there is only one object type attribute i.e ocean_proximity while all other are numbers

# %%
df.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                  41          880           129.0
# 1    -122.22     37.86                  21         7099          1106.0
# 2    -122.24     37.85                  52         1467           190.0
# 3    -122.25     37.85                  52         1274           235.0
# 4    -122.25     37.85                  52         1627           280.0
#
#    population  households  median_income  median_house_value ocean_proximity
# 0         322         126         8.3252              452600        NEAR BAY
# 1        2401        1138         8.3014              358500        NEAR BAY
# 2         496         177         7.2574              352100        NEAR BAY
# 3         558         219         5.6431              341300        NEAR BAY
# 4         565         259         3.8462              342200        NEAR BAY

# %%
df.corr()
# Out:
#                     longitude  latitude  housing_median_age  total_rooms  \
# longitude            1.000000 -0.927885           -0.157871     0.049984
# latitude            -0.927885  1.000000            0.054146    -0.032655
# housing_median_age  -0.157871  0.054146            1.000000    -0.364390
# total_rooms          0.049984 -0.032655           -0.364390     1.000000
# total_bedrooms       0.069396 -0.061310           -0.325991     0.929230
# population           0.098757 -0.102874           -0.299780     0.853624
# households           0.054619 -0.065344           -0.306834     0.916821
# median_income       -0.013298 -0.062695           -0.117763     0.198413
# median_house_value  -0.056413 -0.116656            0.116142     0.130467
#
#                     total_bedrooms  population  households  median_income  \
# longitude                 0.069396    0.098757    0.054619      -0.013298
# latitude                 -0.061310   -0.102874   -0.065344      -0.062695
# ...

# %%
sns.heatmap(df.corr(),annot=True,cmap='Blues')
# Out:
# <Axes: >

# %% [markdown]
# some insights:
#
#
# 1-  longitude and latitude has a strong  negative correlation. if one would have a higher value , the other will have a lower
#
#
# 2-  another insight is the population , households , totalbed rooms and total rooms has a strong positive relation and it shows that they are directly related to each other

# %% [markdown]
# #  1-distribution plots
# 1- histplot
#
# 2- kdeplot
#
# 3- distplot

# %%
df
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                  41          880           129.0
# 1        -122.22     37.86                  21         7099          1106.0
# 2        -122.24     37.85                  52         1467           190.0
# 3        -122.25     37.85                  52         1274           235.0
# 4        -122.25     37.85                  52         1627           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                  25         1665           374.0
# 20636    -121.21     39.49                  18          697           150.0
# 20637    -121.22     39.43                  17         2254           485.0
# 20638    -121.32     39.43                  18         1860           409.0
# 20639    -121.24     39.37                  16         2785           616.0
#
# ...

# %%
plt.figure(figsize=(10,10))
sns.histplot(df['median_house_value'])
# Out:
# <Axes: xlabel='median_house_value', ylabel='Count'>

# %%
sns.kdeplot(df['median_house_value'])
# Out:
# <Axes: xlabel='median_house_value', ylabel='Density'>

# %% [markdown]
# # relational plot
#
# 1- relplot
#
# 2- scatterplot
#
# 3-  lineplot

# %%
sns.scatterplot(df,x='median_house_value',y='total_rooms')
# Out:
# <Axes: xlabel='median_house_value', ylabel='total_rooms'>

# %%
df.head(

)
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                  41          880           129.0
# 1    -122.22     37.86                  21         7099          1106.0
# 2    -122.24     37.85                  52         1467           190.0
# 3    -122.25     37.85                  52         1274           235.0
# 4    -122.25     37.85                  52         1627           280.0
#
#    population  households  median_income  median_house_value ocean_proximity
# 0         322         126         8.3252              452600        NEAR BAY
# 1        2401        1138         8.3014              358500        NEAR BAY
# 2         496         177         7.2574              352100        NEAR BAY
# 3         558         219         5.6431              341300        NEAR BAY
# 4         565         259         3.8462              342200        NEAR BAY

# %%
sns.lineplot(df,x='total_rooms',y='population')
# Out:
# <Axes: xlabel='total_rooms', ylabel='population'>

# %% [markdown]
# # CATEGORICAL PLOTS;
# 1-  BAR PLOT
#
# 2-  BOX PLOT
#
# 3-  BOXEN PLOT
#
# 4-  STRIP PLOT
#
# 5-  SWARM PLOT
#
# 6-  POINT PLOT
#
# 7-  VIOLIN PLOT

# %%
plt.figure(figsize=(19,5))
sns.barplot(df,x='ocean_proximity',y='median_house_value')
# Out:
# <Axes: xlabel='ocean_proximity', ylabel='median_house_value'>

# %% [markdown]
# it shows that the prices of housing socities are higher near island and it is mostly lower near inland

# %%
sns.boxplot(df,x='ocean_proximity',y='median_house_value')
# Out:
# <Axes: xlabel='ocean_proximity', ylabel='median_house_value'>

# %% [markdown]
# it shows that there are many outliers in the house value in inland

# %%
sns.swarmplot(df,x='ocean_proximity',y='median_house_value')
# Out:
# <Axes: xlabel='ocean_proximity', ylabel='median_house_value'>
# Error in callback <function _draw_all_if_interactive at 0x7cefdec5e050> (for post_execute):
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/matplotlib/pyplot.py in _draw_all_if_interactive()
#     118 def _draw_all_if_interactive():
#     119     if matplotlib.is_interactive():
# --> 120         draw_all()
#     121
#     122
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/_pylab_helpers.py in draw_all(cls, force)
#     130         for manager in cls.get_all_fig_managers():
#     131             if force or manager.canvas.figure.stale:
# --> 132                 manager.canvas.draw_idle()
#     133
#     134
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/backend_bases.py in draw_idle(self, *args, **kwargs)
#    2080         if not self._is_idle_drawing:
# ...

# %%
sns.stripplot(df,x='ocean_proximity',y='median_house_value',palette='Reds')
# Out:
# <Axes: xlabel='ocean_proximity', ylabel='median_house_value'>

# %%
sns.pointplot(df,x='ocean_proximity',y='median_house_value')
# Out:
# <Axes: xlabel='ocean_proximity', ylabel='median_house_value'>

# %%
sns.violinplot(df,x='ocean_proximity',y='median_house_value')
# Out:
# <Axes: xlabel='ocean_proximity', ylabel='median_house_value'>

# %%
df
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                  41          880           129.0
# 1        -122.22     37.86                  21         7099          1106.0
# 2        -122.24     37.85                  52         1467           190.0
# 3        -122.25     37.85                  52         1274           235.0
# 4        -122.25     37.85                  52         1627           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                  25         1665           374.0
# 20636    -121.21     39.49                  18          697           150.0
# 20637    -121.22     39.43                  17         2254           485.0
# 20638    -121.32     39.43                  18         1860           409.0
# 20639    -121.24     39.37                  16         2785           616.0
#
# ...

# %%
sns.countplot(df,x='ocean_proximity',)
# Out:
# <Axes: xlabel='ocean_proximity', ylabel='count'>

# %%
a=sns.FacetGrid(df,row='ocean_proximity')
a.map(plt.hist,'median_income')
a.add_legend()

# %% [markdown]
# it gives us the insight that the inland people has more ncome

# %%
df['ocean_proximity'].value_counts()
# Out:
# <1H OCEAN     9136
# INLAND        6551
# NEAR OCEAN    2658
# NEAR BAY      2290
# ISLAND           5
# Name: ocean_proximity, dtype: int64

# %% [markdown]
# #c. Clean the dataset, remove the missing values as mentioned in the Lectures 15

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20640 non-null  float64
#  1   latitude            20640 non-null  float64
#  2   housing_median_age  20640 non-null  int64
#  3   total_rooms         20640 non-null  int64
#  4   total_bedrooms      20433 non-null  float64
#  5   population          20640 non-null  int64
#  6   households          20640 non-null  int64
#  7   median_income       20640 non-null  float64
#  8   median_house_value  20640 non-null  int64
#  9   ocean_proximity     20640 non-null  object
# dtypes: float64(4), int64(5), object(1)
# memory usage: 1.6+ MB

# %%
sns.boxplot(df,x='ocean_proximity',y='median_house_value')
# Out:
# <Axes: xlabel='ocean_proximity', ylabel='median_house_value'>

# %%
df.describe(

)
# Out:
#           longitude      latitude  housing_median_age   total_rooms  \
# count  20640.000000  20640.000000        20640.000000  20640.000000
# mean    -119.569704     35.631861           28.639486   2635.763081
# std        2.003532      2.135952           12.585558   2181.615252
# min     -124.350000     32.540000            1.000000      2.000000
# 25%     -121.800000     33.930000           18.000000   1447.750000
# 50%     -118.490000     34.260000           29.000000   2127.000000
# 75%     -118.010000     37.710000           37.000000   3148.000000
# max     -114.310000     41.950000           52.000000  39320.000000
#
#        total_bedrooms    population    households  median_income  \
# count    20433.000000  20640.000000  20640.000000   20640.000000
# mean       537.870553   1425.476744    499.539680       3.870671
# std        421.385070   1132.462122    382.329753       1.899822
# min          1.000000      3.000000      1.000000       0.499900
# ...

# %% [markdown]
# as we know that there are some missing values out there in the total bedrooms attribute so i gonna replace them with the median value
#
# we can calculate the median by getting the mean of q1 and q3 as follows:
#
# #median =  296+647/2== 471 rounding off

# %%
def replacing_median(columnn,median):
  df[columnn]=df[columnn].fillna(median)
  return df

replacing_median('total_bedrooms',471)
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                  41          880           129.0
# 1        -122.22     37.86                  21         7099          1106.0
# 2        -122.24     37.85                  52         1467           190.0
# 3        -122.25     37.85                  52         1274           235.0
# 4        -122.25     37.85                  52         1627           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                  25         1665           374.0
# 20636    -121.21     39.49                  18          697           150.0
# 20637    -121.22     39.43                  17         2254           485.0
# 20638    -121.32     39.43                  18         1860           409.0
# 20639    -121.24     39.37                  16         2785           616.0
#
# ...

# %%
df.info(

)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20640 non-null  float64
#  1   latitude            20640 non-null  float64
#  2   housing_median_age  20640 non-null  int64
#  3   total_rooms         20640 non-null  int64
#  4   total_bedrooms      20640 non-null  float64
#  5   population          20640 non-null  int64
#  6   households          20640 non-null  int64
#  7   median_income       20640 non-null  float64
#  8   median_house_value  20640 non-null  int64
#  9   ocean_proximity     20640 non-null  object
# dtypes: float64(4), int64(5), object(1)
# memory usage: 1.6+ MB

# %% [markdown]
# now it is a fine dataset

# %% [markdown]
# i have removed the missing values and replaced them with the median of total_bedrooms and now the data is cleaned

# %% [markdown]
# # d. Select the target variable and clearly mention the reason for selecting it.

# %% [markdown]
# #I have selected the median_house_value as a target variable. it is because:
#
# 1-   it is a dependent variable and it depends one a lot of characteristics there.
#
# for example,
#
#  it depends upon the longitude , latitude , the no of rooms , no of bedrooms, the population and the median income of the households
#
# 2-   it is such a variable which can be important for a person who wants to get the insights of the data and who wants to train a model to predict the price of the house depending upon on several factors as some in our data
#
#
# 3-it is such a varible which one would like to predict

# %% [markdown]
# # e. Separate the target variable from the data set.

# %%
target_variable=df['median_house_value']
target_variable.head(9)
# Out:
# 0    452600
# 1    358500
# 2    352100
# 3    341300
# 4    342200
# 5    269700
# 6    299200
# 7    241400
# 8    226700
# Name: median_house_value, dtype: int64

# %% [markdown]
# converting object i.e ocean attribute to category

# %%
df['ocean_proximity']=df['ocean_proximity'].astype('category')

# %%
df.dtypes
# Out:
# longitude              float64
# latitude               float64
# housing_median_age       int64
# total_rooms              int64
# total_bedrooms         float64
# population               int64
# households               int64
# median_income          float64
# median_house_value       int64
# ocean_proximity       category
# dtype: object

# %% [markdown]
# converting categorical variable into dummy or indicator variable

# %%
df.head(

)
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                  41          880           129.0
# 1    -122.22     37.86                  21         7099          1106.0
# 2    -122.24     37.85                  52         1467           190.0
# 3    -122.25     37.85                  52         1274           235.0
# 4    -122.25     37.85                  52         1627           280.0
#
#    population  households  median_income  median_house_value ocean_proximity  \
# 0         322         126         8.3252              452600        NEAR BAY
# 1        2401        1138         8.3014              358500        NEAR BAY
# 2         496         177         7.2574              352100        NEAR BAY
# 3         558         219         5.6431              341300        NEAR BAY
# 4         565         259         3.8462              342200        NEAR BAY
#
#    INLAND  ISLAND  NEAR BAY  NEAR OCEAN
# ...

# %%
df.drop('ocean_proximity',axis=1)
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                  41          880           129.0
# 1        -122.22     37.86                  21         7099          1106.0
# 2        -122.24     37.85                  52         1467           190.0
# 3        -122.25     37.85                  52         1274           235.0
# 4        -122.25     37.85                  52         1627           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                  25         1665           374.0
# 20636    -121.21     39.49                  18          697           150.0
# 20637    -121.22     39.43                  17         2254           485.0
# 20638    -121.32     39.43                  18         1860           409.0
# 20639    -121.24     39.37                  16         2785           616.0
#
# ...

# %% [markdown]
# now the data is ready for the training of the model

# %% [markdown]
# # 2. Use the Scikit Learn Library to fit the Classification model
# a. Split the data into train test sets
#
#
# b. Use logistic regression to train the model
#
#
# c. Test the model and display the accuracy of the model.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 9 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20640 non-null  float64
#  1   latitude            20640 non-null  float64
#  2   housing_median_age  20640 non-null  int64
#  3   total_rooms         20640 non-null  int64
#  4   total_bedrooms      20640 non-null  float64
#  5   population          20640 non-null  int64
#  6   households          20640 non-null  int64
#  7   median_income       20640 non-null  float64
#  8   median_house_value  20640 non-null  int64
# dtypes: float64(4), int64(5)
# memory usage: 1.4 MB

# %%
df
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                  41          880           129.0
# 1        -122.22     37.86                  21         7099          1106.0
# 2        -122.24     37.85                  52         1467           190.0
# 3        -122.25     37.85                  52         1274           235.0
# 4        -122.25     37.85                  52         1627           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                  25         1665           374.0
# 20636    -121.21     39.49                  18          697           150.0
# 20637    -121.22     39.43                  17         2254           485.0
# 20638    -121.32     39.43                  18         1860           409.0
# 20639    -121.24     39.37                  16         2785           616.0
#
# ...

# %%
df.drop(['INLAND',	'ISLAND'	,'NEAR BAY','NEAR OCEAN'],axis=1)
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                  41          880           129.0
# 1        -122.22     37.86                  21         7099          1106.0
# 2        -122.24     37.85                  52         1467           190.0
# 3        -122.25     37.85                  52         1274           235.0
# 4        -122.25     37.85                  52         1627           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                  25         1665           374.0
# 20636    -121.21     39.49                  18          697           150.0
# 20637    -121.22     39.43                  17         2254           485.0
# 20638    -121.32     39.43                  18         1860           409.0
# 20639    -121.24     39.37                  16         2785           616.0
#
# ...

# %%
df.dropna(inplace=True)

# %%
x = df.drop('ocean_proximity', axis = 1)
y = df['ocean_proximity']

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = .20, random_state =99000)

# %%
from sklearn.linear_model import LogisticRegression
lreg = LogisticRegression()
lreg.fit(x_train, y_train)
# Out:
# LogisticRegression()

# %%
y_pred_lreg = lreg.predict(x_test)
print(y_pred_lreg)
# Out:
# ['INLAND' '<1H OCEAN' '<1H OCEAN' ... '<1H OCEAN' '<1H OCEAN' '<1H OCEAN']

# %%
from sklearn.metrics import classification_report, accuracy_score

print('Classification Model')
# Accuracy
print('--'*30)
logreg_accuracy = round(accuracy_score(y_test, y_pred_lreg) * 100,2)
print('Accuracy', logreg_accuracy,'%')
# Out:
# Classification Model
# ------------------------------------------------------------
# Accuracy 42.65 %

# %%
df
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                  41          880           129.0
# 1        -122.22     37.86                  21         7099          1106.0
# 2        -122.24     37.85                  52         1467           190.0
# 3        -122.25     37.85                  52         1274           235.0
# 4        -122.25     37.85                  52         1627           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                  25         1665           374.0
# 20636    -121.21     39.49                  18          697           150.0
# 20637    -121.22     39.43                  17         2254           485.0
# 20638    -121.32     39.43                  18         1860           409.0
# 20639    -121.24     39.37                  16         2785           616.0
#
# ...
